# %% [markdown]
# # Classifier for Loan Deafult IBM-Coursera (Peer_graded assessment)
#
# This is a peer graded assessment test/examination of IBM-COursera certification  Machine Learning With Pyton.
# We will be doing classification problem on Loan_train dataset to predict the defaulting and genuine customers.
#
# Logistic regression, Support Vector Machine, K-Nearest Neighbour and Decision Tree models are built , applied on the data set and evaluated using Jaccard index ,F1-score ,LogLoass as mentioned in the test question.

# %%
loan_train_csv= "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_train.csv"
loan_test_csv = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
#reading loan_train_csv

df_train= pd.read_csv(loan_train_csv,  parse_dates=True)
df_test = pd.read_csv(loan_test_csv,  parse_dates=True)

# %% [markdown]
# To reducing number of  preprocessing operations on train and test set we will combine both dataframes. After preprocessing whole data framewe will split them again.

# %%
df_train = df_train.append(df_test)

# %%
#dispaly top few records
df_train.shape
# Out:
# (400, 10)

# %% [markdown]
# Field	Description
#
# Loan_status	Whether a loan is paid off on in collection
#
# Principal	Basic principal loan amount at the
#
# Terms	Origination terms which can be weekly (7 days), biweekly, and monthly payoff schedule
#
# Effective_date	When the loan got originated and took effects
#
# Due_date	Since it’s one-time payoff schedule, each loan has one single due date
#
# Age	Age of applicant
#
# Education	Education of applicant
#
# Gender	The gender of applicant

# %%
#rename columns
columns = df_train.columns
columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'loan_status', 'Principal', 'terms',
#        'effective_date', 'due_date', 'age', 'education', 'Gender'],
#       dtype='object')

# %%
#rename columns 
df_train.rename(columns = { columns[0]:"one" , columns[1]:"two"}, inplace = True)
df_train.columns
# Out:
# Index(['one', 'two', 'loan_status', 'Principal', 'terms', 'effective_date',
#        'due_date', 'age', 'education', 'Gender'],
#       dtype='object')

# %%
#check data types
df_train.dtypes
# Out:
# one                int64
# two                int64
# loan_status       object
# Principal          int64
# terms              int64
# effective_date    object
# due_date          object
# age                int64
# education         object
# Gender            object
# dtype: object

# %%
#converting string dates  to datetime 
df_train['effective_date'] = pd.to_datetime(df_train['effective_date'])
df_train['due_date'] = pd.to_datetime(df_train['due_date'])
df_train.dtypes
# Out:
# one                        int64
# two                        int64
# loan_status               object
# Principal                  int64
# terms                      int64
# effective_date    datetime64[ns]
# due_date          datetime64[ns]
# age                        int64
# education                 object
# Gender                    object
# dtype: object

# %%
#check null values
df_train.isna().sum()
# Out:
# one               0
# two               0
# loan_status       0
# Principal         0
# terms             0
# effective_date    0
# due_date          0
# age               0
# education         0
# Gender            0
# dtype: int64

# %% [markdown]
# Hence no missing values.

# %%
df_train.head(10)
# Out:
#    one  two loan_status  Principal  terms effective_date   due_date  age  \
# 0    0    0     PAIDOFF       1000     30     2016-09-08 2016-10-07   45
# 1    2    2     PAIDOFF       1000     30     2016-09-08 2016-10-07   33
# 2    3    3     PAIDOFF       1000     15     2016-09-08 2016-09-22   27
# 3    4    4     PAIDOFF       1000     30     2016-09-09 2016-10-08   28
# 4    6    6     PAIDOFF       1000     30     2016-09-09 2016-10-08   29
# 5    7    7     PAIDOFF       1000     30     2016-09-09 2016-10-08   36
# 6    8    8     PAIDOFF       1000     30     2016-09-09 2016-10-08   28
# 7    9    9     PAIDOFF        800     15     2016-09-10 2016-09-24   26
# 8   10   10     PAIDOFF        300      7     2016-09-10 2016-09-16   29
# 9   11   11     PAIDOFF       1000     15     2016-09-10 2016-10-09   39
#
#               education  Gender
# 0  High School or Below    male
# 1              Bechalor  female
# 2               college    male
# 3               college  female
# 4               college    male
# 5               college    male
# 6               college    male
# 7               college    male
# 8               college    male
# 9  High School or Below    male

# %%
#checking types of unique values 
df_train.education.unique() # 4 unique
df_train.loan_status.unique() #two uniques
# Out:
# array(['PAIDOFF', 'COLLECTION'], dtype=object)

# %%
#convrt gender colum to numeric values -- 0- male, 1- female
from sklearn.preprocessing import LabelEncoder
genderEncoder= LabelEncoder()
df_train.Gender = genderEncoder.fit_transform(df_train.Gender)
df_train.head()
# Out:
#    one  two loan_status  Principal  terms effective_date   due_date  age  \
# 0    0    0     PAIDOFF       1000     30     2016-09-08 2016-10-07   45
# 1    2    2     PAIDOFF       1000     30     2016-09-08 2016-10-07   33
# 2    3    3     PAIDOFF       1000     15     2016-09-08 2016-09-22   27
# 3    4    4     PAIDOFF       1000     30     2016-09-09 2016-10-08   28
# 4    6    6     PAIDOFF       1000     30     2016-09-09 2016-10-08   29
#
#               education  Gender
# 0  High School or Below       1
# 1              Bechalor       0
# 2               college       1
# 3               college       0
# 4               college       1

# %%
edu_dummy= pd.get_dummies(df_train.education)
edu_dummy
df_train.drop(axis=1, columns= "education", inplace= True)
df_train = pd.concat( [df_train,edu_dummy ], axis=1 )

# %%
#convert loan_status  to numeric values 1- paid, 0- default
loan_status_encoder =LabelEncoder()
df_train.loan_status = loan_status_encoder.fit_transform(df_train.loan_status)
df_train.head()
# Out:
#    one  two  loan_status  Principal  terms effective_date   due_date  age  \
# 0    0    0            1       1000     30     2016-09-08 2016-10-07   45
# 1    2    2            1       1000     30     2016-09-08 2016-10-07   33
# 2    3    3            1       1000     15     2016-09-08 2016-09-22   27
# 3    4    4            1       1000     30     2016-09-09 2016-10-08   28
# 4    6    6            1       1000     30     2016-09-09 2016-10-08   29
#
#    Gender  Bechalor  High School or Below  Master or Above  college
# 0       1         0                     1                0        0
# 1       0         1                     0                0        0
# 2       1         0                     0                0        1
# 3       0         0                     0                0        1
# 4       1         0                     0                0        1

# %%
# create method to add date parts . This method is a part of fast ai library
from pandas.api.types import *
import re
def add_datepart(df, fldname, drop=True, time=False, errors="raise"):	
    """add_datepart converts a column of df from a datetime64 to many columns containing
    the information from the date. This applies changes inplace.
    Parameters:
    -----------
    df: A pandas data frame. df gain several new columns.
    fldname: A string that is the name of the date column you wish to expand.
        If it is not a datetime64 series, it will be converted to one with pd.to_datetime.
    drop: If true then the original date column will be removed.
    time: If true time features: Hour, Minute, Second will be added.
    
    """
    
    fld = df[fldname]
    fld_dtype = fld.dtype
    if isinstance(fld_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        fld_dtype = np.datetime64

    if not np.issubdtype(fld_dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True, errors=errors)
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    attr = ['Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear',
            'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
    if time: attr = attr + ['Hour', 'Minute', 'Second']
    for n in attr: df[targ_pre + n] = getattr(fld.dt, n.lower())
    df[targ_pre + 'Elapsed'] = fld.astype(np.int64) // 10 ** 9
    if drop: df.drop(fldname, axis=1, inplace=True)

def is_date(x): return np.issubdtype(x.dtype, np.datetime64)

# %%
#separating target varible and independent avriables
X = df_train.loc[:, df_train.columns != 'loan_status']
Y = df_train.loan_status

# %% [markdown]
# Converting date into dateparts like quarter, day of year,day of week etc.

# %%
add_datepart(X, fldname= 'effective_date')
add_datepart(X, fldname= 'due_date')
X
# Out:
#     one  two  Principal  terms  age  Gender  Bechalor  High School or Below  \
# 0     0    0       1000     30   45       1         0                     1
# 1     2    2       1000     30   33       0         1                     0
# 2     3    3       1000     15   27       1         0                     0
# 3     4    4       1000     30   28       0         0                     0
# 4     6    6       1000     30   29       1         0                     0
# 5     7    7       1000     30   36       1         0                     0
# 6     8    8       1000     30   28       1         0                     0
# 7     9    9        800     15   26       1         0                     0
# 8    10   10        300      7   29       1         0                     0
# 9    11   11       1000     15   39       1         0                     1
# 10   12   12       1000     30   26       1         0                     0
# 11   13   13        900      7   26       0         0                     0
# 12   14   14       1000      7   27       1         0                     1
# 13   15   15        800     15   26       1         0                     0
# 14   16   16       1000     30   40       1         0                     1
# 15   17   17       1000     15   32       1         0                     1
# 16   18   18       1000     30   32       1         0                     1
# 17   19   19        800     30   26       1         0                     0
# 18   20   20       1000     30   26       1         0                     0
# 19   22   22       1000     30   25       1         0                     1
# 20   23   23       1000     15   26       1         0                     0
# 21   25   25       1000     30   29       1         0                     1
# 22   26   26        800     15   39       1         1                     0
# 23   27   27       1000     15   34       1         1                     0
# 24   28   28       1000     30   31       1         0                     0
# 25   29   29       1000     30   33       1         0                     0
# 26   30   30        800     15   33       1         0                     1
# 27   31   31       1000     30   37       1         0                     0
# 28   32   32       1000     30   27       1         0                     0
# 29   33   33       1000     30   37       1         0                     0
# ..  ...  ...        ...    ...  ...     ...       ...                   ...
# 24  156  156       1000     15   26       1         1                     0
# 25  167  167        800     30   28       1         0                     0
# 26  169  169       1000     30   38       1         0                     0
# 27  179  179       1000     30   46       1         0                     0
# 28  186  186       1000     30   33       1         1                     0
# 29  196  196       1000     30   29       1         0                     0
# 30  199  199       1000     30   29       1         0                     0
# 31  202  202       1000     15   36       1         0                     1
# 32  222  222       1000     30   29       1         0                     0
# 33  236  236       1000     30   30       1         0                     0
# 34  239  239       1000     15   36       1         0                     1
# 35  251  251       1000     30   29       1         0                     0
# 36  252  252       1000     30   28       1         0                     1
# 37  264  264        800     15   23       1         0                     0
# 38  287  287       1000     30   38       0         0                     1
# 39  295  295       1000     30   30       0         0                     0
# 40  302  302       1000     30   33       1         0                     1
# 41  305  305       1000     15   31       0         0                     1
# 42  309  309        800     15   41       1         0                     0
# 43  310  310       1000     30   30       1         0                     0
# 44  311  311        800     15   26       0         0                     1
# 45  313  313       1000     30   20       1         0                     1
# 46  315  315       1000     15   26       1         0                     1
# 47  328  328       1000     30   24       0         0                     1
# 48  331  331        800     15   27       1         0                     0
# 49  348  348       1000     30   32       1         0                     1
# 50  349  349        800     15   29       1         0                     0
# 51  369  369       1000     30   37       1         0                     1
# 52  370  370        800     15   36       1         0                     1
# 53  396  396       1000     30   33       1         0                     1
#
#     Master or Above  college     ...       due_Day  due_Dayofweek  \
# 0                 0        0     ...             7              4
# 1                 0        0     ...             7              4
# 2                 0        1     ...            22              3
# 3                 0        1     ...             8              5
# 4                 0        1     ...             8              5
# 5                 0        1     ...             8              5
# 6                 0        1     ...             8              5
# 7                 0        1     ...            24              5
# 8                 0        1     ...            16              4
# 9                 0        0     ...             9              6
# 10                0        1     ...             9              6
# 11                0        1     ...            16              4
# 12                0        0     ...            16              4
# 13                0        1     ...            24              5
# 14                0        0     ...             9              6
# 15                0        0     ...            24              5
# 16                0        0     ...             9              6
# 17                0        1     ...             9              6
# 18                0        1     ...             9              6
# 19                0        0     ...             9              6
# 20                0        1     ...            24              5
# 21                0        0     ...             9              6
# 22                0        0     ...            24              5
# 23                0        0     ...            24              5
# 24                0        1     ...            10              0
# 25                0        1     ...            10              0
# 26                0        0     ...            25              6
# 27                0        1     ...            10              0
# 28                0        1     ...            10              0
# 29                0        1     ...            10              0
# ..              ...      ...     ...           ...            ...
# 24                0        0     ...            26              0
# 25                0        1     ...            11              1
# 26                0        1     ...            11              1
# 27                0        1     ...            11              1
# 28                0        0     ...            11              1
# 29                0        1     ...            10              3
# 30                0        1     ...            11              1
# 31                0        0     ...            26              0
# 32                0        1     ...            10              3
# 33                0        1     ...            11              1
# 34                0        0     ...            26              0
# 35                0        1     ...            12              2
# 36                0        0     ...            12              2
# 37                0        1     ...            27              1
# 38                0        0     ...            13              3
# 39                0        1     ...            13              3
# 40                0        0     ...             8              5
# 41                0        0     ...            24              5
# 42                0        1     ...            24              5
# 43                0        1     ...             9              6
# 44                0        0     ...            24              5
# 45                0        0     ...             9              6
# 46                0        0     ...             9              6
# 47                0        0     ...            10              0
# 48                0        1     ...            25              6
# 49                0        0     ...            10              0
# 50                0        1     ...            25              6
# 51                0        0     ...            10              0
# 52                0        0     ...            25              6
# 53                0        0     ...            11              1
#
#     due_Dayofyear  due_Is_month_end  due_Is_month_start  due_Is_quarter_end  \
# 0             281             False               False               False
# 1             281             False               False               False
# 2             266             False               False               False
# 3             282             False               False               False
# 4             282             False               False               False
# 5             282             False               False               False
# 6             282             False               False               False
# 7             268             False               False               False
# 8             260             False               False               False
# 9             283             False               False               False
# 10            283             False               False               False
# 11            260             False               False               False
# 12            260             False               False               False
# 13            268             False               False               False
# 14            283             False               False               False
# 15            268             False               False               False
# 16            283             False               False               False
# 17            283             False               False               False
# 18            283             False               False               False
# 19            283             False               False               False
# 20            268             False               False               False
# 21            283             False               False               False
# 22            268             False               False               False
# 23            268             False               False               False
# 24            284             False               False               False
# 25            284             False               False               False
# 26            269             False               False               False
# 27            284             False               False               False
# 28            284             False               False               False
# 29            284             False               False               False
# ..            ...               ...                 ...                 ...
# 24            270             False               False               False
# 25            285             False               False               False
# 26            285             False               False               False
# 27            285             False               False               False
# 28            285             False               False               False
# 29            315             False               False               False
# 30            285             False               False               False
# 31            270             False               False               False
# 32            315             False               False               False
# 33            285             False               False               False
# 34            270             False               False               False
# 35            286             False               False               False
# 36            286             False               False               False
# 37            271             False               False               False
# 38            287             False               False               False
# 39            287             False               False               False
# 40            282             False               False               False
# 41            268             False               False               False
# 42            268             False               False               False
# 43            283             False               False               False
# 44            268             False               False               False
# 45            283             False               False               False
# 46            283             False               False               False
# 47            284             False               False               False
# 48            269             False               False               False
# 49            284             False               False               False
# 50            269             False               False               False
# 51            284             False               False               False
# 52            269             False               False               False
# 53            285             False               False               False
#
#     due_Is_quarter_start  due_Is_year_end  due_Is_year_start  due_Elapsed
# 0                  False            False              False   1475798400
# 1                  False            False              False   1475798400
# 2                  False            False              False   1474502400
# 3                  False            False              False   1475884800
# 4                  False            False              False   1475884800
# 5                  False            False              False   1475884800
# 6                  False            False              False   1475884800
# 7                  False            False              False   1474675200
# 8                  False            False              False   1473984000
# 9                  False            False              False   1475971200
# 10                 False            False              False   1475971200
# 11                 False            False              False   1473984000
# 12                 False            False              False   1473984000
# 13                 False            False              False   1474675200
# 14                 False            False              False   1475971200
# 15                 False            False              False   1474675200
# 16                 False            False              False   1475971200
# 17                 False            False              False   1475971200
# 18                 False            False              False   1475971200
# 19                 False            False              False   1475971200
# 20                 False            False              False   1474675200
# 21                 False            False              False   1475971200
# 22                 False            False              False   1474675200
# 23                 False            False              False   1474675200
# 24                 False            False              False   1476057600
# 25                 False            False              False   1476057600
# 26                 False            False              False   1474761600
# 27                 False            False              False   1476057600
# 28                 False            False              False   1476057600
# 29                 False            False              False   1476057600
# ..                   ...              ...                ...          ...
# 24                 False            False              False   1474848000
# 25                 False            False              False   1476144000
# 26                 False            False              False   1476144000
# 27                 False            False              False   1476144000
# 28                 False            False              False   1476144000
# 29                 False            False              False   1478736000
# 30                 False            False              False   1476144000
# 31                 False            False              False   1474848000
# 32                 False            False              False   1478736000
# 33                 False            False              False   1476144000
# 34                 False            False              False   1474848000
# 35                 False            False              False   1476230400
# 36                 False            False              False   1476230400
# 37                 False            False              False   1474934400
# 38                 False            False              False   1476316800
# 39                 False            False              False   1476316800
# 40                 False            False              False   1475884800
# 41                 False            False              False   1474675200
# 42                 False            False              False   1474675200
# 43                 False            False              False   1475971200
# 44                 False            False              False   1474675200
# 45                 False            False              False   1475971200
# 46                 False            False              False   1475971200
# 47                 False            False              False   1476057600
# 48                 False            False              False   1474761600
# 49                 False            False              False   1476057600
# 50                 False            False              False   1474761600
# 51                 False            False              False   1476057600
# 52                 False            False              False   1474761600
# 53                 False            False              False   1476144000
#
# [400 rows x 36 columns]

# %% [markdown]
# Finally, we have all values numeric in the dataframe. It is ready to normalize and apply to model.

# %%
X.dtypes
# Out:
# one                           int64
# two                           int64
# Principal                     int64
# terms                         int64
# age                           int64
# Gender                        int64
# Bechalor                      uint8
# High School or Below          uint8
# Master or Above               uint8
# college                       uint8
# effective_Year                int64
# effective_Month               int64
# effective_Week                int64
# effective_Day                 int64
# effective_Dayofweek           int64
# effective_Dayofyear           int64
# effective_Is_month_end         bool
# effective_Is_month_start       bool
# effective_Is_quarter_end       bool
# effective_Is_quarter_start     bool
# effective_Is_year_end          bool
# effective_Is_year_start        bool
# effective_Elapsed             int64
# due_Year                      int64
# due_Month                     int64
# due_Week                      int64
# due_Day                       int64
# due_Dayofweek                 int64
# due_Dayofyear                 int64
# due_Is_month_end               bool
# due_Is_month_start             bool
# due_Is_quarter_end             bool
# due_Is_quarter_start           bool
# due_Is_year_end                bool
# due_Is_year_start              bool
# due_Elapsed                   int64
# dtype: object

# %% [markdown]
# # Scalling data

# %%
from sklearn.preprocessing import StandardScaler
X_normalized = StandardScaler().fit(X).transform(X)
X_normalized[0:3]
# Out:
# array([[-1.72772608, -1.72772608,  0.50130175,  0.92089421,  2.31334964,
#          0.43236977, -0.38655567,  1.15133896, -0.10050378, -0.86855395,
#          0.        ,  0.        , -0.80379757, -2.99072091, -0.26462433,
#         -2.99072091,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        , -2.99072091,  0.        ,  0.72049117,
#          0.05549036, -1.33593342,  0.61329721,  0.20072177,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.20072177],
#        [-1.71040552, -1.71040552,  0.50130175,  0.92089421,  0.32194392,
#         -2.31283513,  2.5869495 , -0.86855395, -0.10050378, -0.86855395,
#          0.        ,  0.        , -0.80379757, -2.99072091, -0.26462433,
#         -2.99072091,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        , -2.99072091,  0.        ,  0.72049117,
#          0.05549036, -1.33593342,  0.61329721,  0.20072177,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.20072177],
#        [-1.70174524, -1.70174524,  0.50130175, -0.9332552 , -0.67375893,
#          0.43236977, -0.38655567, -0.86855395, -0.10050378,  1.15133896,
#          0.        ,  0.        , -0.80379757, -2.99072091, -0.26462433,
#         -2.99072091,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        , -2.99072091,  0.        , -1.05849937,
#         -1.11272776,  0.68514588,  0.21310327, -1.1693927 ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#         -1.1693927 ]])

# %% [markdown]
# # Feature Selection PCA

# %%
from sklearn import decomposition
pca = decomposition.PCA(n_components=4)
X = pca.fit_transform(X)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split (X, Y, test_size= 0.2, random_state= 0)

# %%
#class counts in target variable
print(df_train.loan_status.value_counts())

df_train.loan_status.value_counts().plot.bar(rot=0)
plot.show()

print(Y_valid.value_counts())
Y_valid.value_counts().plot.bar(rot=0)
plot.show()
# Out:
# 1    300
# 0    100
# Name: loan_status, dtype: int64
# 1    59
# 0    21
# Name: loan_status, dtype: int64

# %% [markdown]
# 1-Paid off, 0- collection .In testing records we have 59 paid loans and 21 defaulted cases.

# %% [markdown]
# # Building model using Logistic Regression

# %%
#Logistic model
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train,Y_train)

#
y_pred_LR =logreg.predict(X_valid)

from sklearn.metrics import accuracy_score
print(accuracy_score(Y_valid, y_pred_LR))

from sklearn.metrics import confusion_matrix
confusion_matrix(Y_valid, y_pred_LR)
# Out:
# 0.975
# array([[21,  0],
#        [ 2, 57]])

# %% [markdown]
# We can see the Logistic Regression fails to classify default records. It has classified 21/21 default cases but fails to predict 2 genuin cases.

# %% [markdown]
# # Building model using Decision Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
DT.fit(X_train,Y_train)
#DT

y_pred_DT=DT.predict(X_valid)
print(accuracy_score(Y_valid, y_pred_DT))


from sklearn.metrics import confusion_matrix
confusion_matrix(Y_valid, y_pred_DT)
# Out:
# 1.0
# array([[21,  0],
#        [ 0, 59]])

# %% [markdown]
# Both classes are predicted with 100percent accuracy. 21/21 defaulted and 59/59 genuine. Hence the best model.

# %% [markdown]
# # Building model using  K- Nearest Neighbour
#
# Notice: Find the best k to build the model with the best accuracy.

# %%
from sklearn.neighbors import KNeighborsClassifier

kmax=20
mean_accuracy=np.zeros(kmax-1)

for k in range(1,kmax):
    
    #Train Model and Predict  
    knn = KNeighborsClassifier(n_neighbors=k).fit(X_train,Y_train)
    ypred = knn.predict(X_valid)
    mean_accuracy[k-1]=np.mean(ypred==Y_valid);
    
    


plot.plot(np.arange(19),mean_accuracy)
plot.xlabel("K value")
plot.ylabel("mean accuracy")
plot.show()
mean_accuracy
# Out:
# array([ 0.95  ,  0.9125,  0.9375,  0.9375,  0.95  ,  0.9125,  0.9125,
#         0.9125,  0.9125,  0.9125,  0.9125,  0.9125,  0.95  ,  0.9125,
#         0.9125,  0.9125,  0.9125,  0.9125,  0.9125])

# %% [markdown]
# Hence, we can observe the maximum accuracy is achieved at K=5 / 13. SO we will consider K=5 as the best K value.

# %%
knn = KNeighborsClassifier(n_neighbors=5).fit(X_train,Y_train)
y_pred_knn = knn.predict(X_valid)

from sklearn.metrics import accuracy_score
print(accuracy_score(Y_valid, y_pred_knn))

from sklearn.metrics import confusion_matrix
confusion_matrix(Y_valid, y_pred_knn)
# Out:
# 0.95
# array([[17,  4],
#        [ 0, 59]])

# %% [markdown]
# # Building model using Support Vector Machine

# %%
from sklearn import svm
svm = svm.SVC(probability=True)
svm.fit(X_train, Y_train)

y_pred_svm = svm.predict(X_valid)

from sklearn.metrics import accuracy_score
print(accuracy_score(Y_valid, y_pred_svm))

from sklearn.metrics import confusion_matrix
confusion_matrix(Y_valid, y_pred_svm)
# Out:
# 0.8
# array([[ 5, 16],
#        [ 0, 59]])

# %% [markdown]
# We can see SVM wrongly predicts 16 defaulted cases .

# %% [markdown]
# # Finding the best Model . Evaluation Using Jaccard Index, F1- Score and and Log Loss

# %%
from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

# %% [markdown]
# # Jaccard Similarity

# %%
# Jaccard for LR 
jcLR = round(jaccard_similarity_score(Y_valid, y_pred_LR),2)
# Jaccard Decision Trees
jcDT = round(jaccard_similarity_score(Y_valid, y_pred_DT),2)
#Jaccard for KNN
jcKNN = round(jaccard_similarity_score(Y_valid, y_pred_knn),2)
# Jaccard for SVM
jcSVM = round(jaccard_similarity_score(Y_valid, y_pred_svm),2)

list_jaccard_similarity  = [jcLR, jcDT, jcKNN, jcSVM]
list_jaccard_similarity
# Out:
# [0.97999999999999998, 1.0, 0.94999999999999996, 0.80000000000000004]

# %% [markdown]
# # F1_score

# %%
fLR = round(f1_score(Y_valid, y_pred_LR, average='weighted'), 2)
fDT = round(f1_score(Y_valid, y_pred_DT, average='weighted'), 2)
fKNN = round(f1_score(Y_valid, y_pred_knn, average='weighted'), 2)
fSVM = round(f1_score(Y_valid, y_pred_svm, average='weighted'),2 )

list_f1_score = [fLR, fDT, fKNN, fSVM]
list_f1_score
# Out:
# [0.97999999999999998, 1.0, 0.94999999999999996, 0.75]

# %% [markdown]
# # Log Loss

# %%
lgloss_LR =log_loss(Y_valid, logreg.predict_proba(X_valid))
lgloss_DT = round(log_loss(Y_valid, DT.predict_proba(X_valid)), 2)
lgloss_KNN =round(log_loss(Y_valid, knn.predict_proba(X_valid)), 2)
lgloss_SVM =round(log_loss(Y_valid, svm.predict_proba(X_valid,)), 2)


list_log_loss = [lgloss_LR, lgloss_DT, lgloss_KNN, lgloss_SVM]
list_log_loss
# Out:
# [0.059956328701964469, 0.0, 0.12, 0.33000000000000002]

# %% [markdown]
# # Final Report on Evaluation

# %%
ind = np.arange(4) 
width = 0.35       
plot.bar(ind, list_jaccard_similarity, width, label='Jaccard Index')
plot.bar(ind + width,  list_f1_score, width,
    label='F1-Score')

plot.ylabel('Scores')
plot.title('Comparision between Jacard similarity and F1- Score')

plot.xticks(ind + width / 2, ('LR', 'DT', 'KNN', 'SVM'))
plot.legend(loc='best')
plot.show()

# %%
width = 0.35       
plot.bar(ind, list_log_loss, width, label='Log Loss Report')

plot.ylabel('Scores')
plot.title('Log Loss Report')

plot.xticks(ind , ('LR', 'DT', 'KNN', 'SVM'))
plot.legend(loc='best')
plot.show()

# %% [markdown]
# ### The lowest log loss, highest jaccard and F1-score in DT. LR stands at second rank. Highest log loss and lowest jaccard similary,f1-score in SVM.  Hence, decision Tree is thebest model for the given problem. AFter that LR is the second best.

# %% [markdown]
# # Precision- Recall Curve

# %% [markdown]
# The precision-recall curve shows the tradeoff between precision and recall for different threshold. A high area under the curve represents both high recall and high precision, where high precision relates to a low false positive rate, and high recall relates to a low false negative rate. High scores for both show that the classifier is returning accurate results (high precision), as well as returning a majority of all positive results (high recall).

# %%
#method to plot - precision- recall curve for model evaluation
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import auc
def plot_prec_recall_curv(ytrue, ypred, title):
    #for a good model  precision and recall both should be high. 
    precision, recall, thresholds = precision_recall_curve(ytrue, ypred)
    auc1 = auc(recall, precision)
    # calculate average precision score
    ap = average_precision_score(ytrue, ypred)
    print(' auc=%.3f ap=%.3f' % ( auc1, ap))
    # plot the precision-recall curve for the model
    plot.plot(recall, precision, marker='.')
    # show the plot
    plot.xlabel("recall")
    plot.ylabel("precision")
    plot.ylim([0.0, 1.05])
    plot.xlim([0.0, 1.0])
    plot.title(title+" PRECISION-RECALL CURVE , AUC: "+ str(auc1) )
    plot.fill_between(recall, precision, alpha=0.2, color='b')
    plot.show()

# %%
#plot recall precision curve
plot_prec_recall_curv(Y_valid, y_pred_LR, title="Logistic Regression Model")

plot_prec_recall_curv(Y_valid, y_pred_DT, title="Decision Tree")

plot_prec_recall_curv(Y_valid, y_pred_knn, title="KNN")

plot_prec_recall_curv(Y_valid, y_pred_svm ,title="SVM")
# Out:
#  auc=0.996 ap=0.991
#  auc=1.000 ap=1.000
#  auc=0.968 ap=0.937
#  auc=0.893 ap=0.787

# %% [markdown]
# ### We can observe from all curves that decision tree has the highest area under precision-recall curve. It gives the best performance. Second best model is the linear regression.

# %% [markdown]
# # F1-score, Jaccard similary and log loss together:

# %%
# printing F1-score, Jaccard similary and log loss together:
df = pd.DataFrame(
    list(zip(
        ['LR','DT','KNN','SVM'],list_jaccard_similarity, list_f1_score, list_log_loss)),
    columns = ['Model', 'Jaccard','F1-Score','Log-Loss']
)

df = pd.DataFrame.from_dict(df)

print(df)
# Out:
#   Model  Jaccard  F1-Score  Log-Loss
# 0    LR     0.98      0.98  0.059956
# 1    DT     1.00      1.00  0.000000
# 2   KNN     0.95      0.95  0.120000
# 3   SVM     0.80      0.75  0.330000
